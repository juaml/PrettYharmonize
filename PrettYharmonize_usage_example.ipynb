# %% [markdown]
# <a   href="https://colab.research.google.com/github.com/juaml/PrettYharmonize/master/PrettYharmonize_usage_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is an example for setting and using PrettYHarmonize

# %% [markdown]
# ## Installation
